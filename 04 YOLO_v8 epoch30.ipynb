# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/classification/yolo_e30
# Out:
# /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/classification/yolo_e30

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/classification/yolo_e30'

# %%
ls

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model= YOLO('yolov8s-cls.pt')
# Out:
# ...
# 100%|██████████| 12.2M/12.2M [00:00<00:00, 123MB/s]

# %%
model.info()
# Out:
# YOLOv8s-cls summary: 99 layers, 6361736 parameters, 0 gradients, 13.6 GFLOPs
# (99, 6361736, 0, 13.609779199999998)

# %%
result = model.train(data = '/content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/E-waste_dataset_preprocessed_updated/main_file_E-waste classification.v1i.folder/',epochs = 30,plots = True, val = True, show= True, batch = 20)
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/classification/yolo_e30/runs/classify/train/weights/best.pt")

# %%
model.info()
# Out:
# YOLOv8s-cls summary: 99 layers, 5088422 parameters, 0 gradients, 12.6 GFLOPs
# (99, 5088422, 0, 12.5919232)

# %%
results = model.predict(source = '/content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/',  project="Test_prediction", name="001",exist_ok=True, save = True)  # return a list of Results objects
# Out:
# image 1/16 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/01.jpeg: 224x224 Monitor 0.78, Laptop 0.21, Mouse 0.01, Other_class 0.00, Keyboard 0.00, 3.6ms
# image 2/16 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/02.jpeg: 224x224 Monitor 1.00, Laptop 0.00, Other_class 0.00, Mobile 0.00, Keyboard 0.00, 10.8ms
# image 3/16 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/03.jpeg: 224x224 Monitor 1.00, Laptop 0.00, Other_class 0.00, Mobile 0.00, Mouse 0.00, 4.1ms
# image 4/16 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/04.jpeg: 224x224 Monitor 1.00, Laptop 0.00, Other_class 0.00, Mouse 0.00, Keyboard 0.00, 3.8ms
# image 5/16 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/05.jpeg: 224x224 Monitor 0.95, Laptop 0.03, Other_class 0.02, Mouse 0.00, Mobile 0.00, 3.7ms
# ...

# %%
image = input("Enter image path")
results = model.predict(image,  project="Predicted_Images", name="001",exist_ok=True, save = True)
# Out:
# Enter image path/content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/09.jpeg
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/testing_images/SELF_taken/09.jpeg: 224x224 Keyboard 1.00, Laptop 0.00, Mobile 0.00, Other_class 0.00, Mouse 0.00, 28.6ms
# Speed: 11.5ms preprocess, 28.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to Predicted_Images/001

# %%
Image(filename='Predicted_Images/001/09.jpeg', width=500)

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
#metrics.top5   # top5 accuracy
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# train: /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/E-waste_dataset_preprocessed_updated/main_file_E-waste classification.v1i.folder/train... found 720 images in 6 classes ✅
# val: /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/E-waste_dataset_preprocessed_updated/main_file_E-waste classification.v1i.folder/val... found 60 images in 6 classes ✅
# test: /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/E-waste_dataset_preprocessed_updated/main_file_E-waste classification.v1i.folder/test... found 60 images in 6 classes ✅
# val: Scanning /content/drive/MyDrive/Colab Notebooks/E-waste_classification_folder/E-waste_dataset_preprocessed_updated/main_file_E-waste classification.v1i.folder/val... 60 images, 0 corrupt: 100%|██████████| 60/60 [00:00<?, ?it/s]
# ...

# %%
# Predict with the model
results = model('/content/drive/MyDrive/Colab Notebooks/testing_images/IMG_20231030_155647.jpg',project="predicted_images_directlink", name="001",exist_ok=True, save = True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/testing_images/IMG_20231030_155647.jpg: 224x224 Keyboard 1.00, Laptop 0.00, Mouse 0.00, Mobile 0.00, Other_class 0.00, 3.9ms
# Speed: 198.6ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to predicted_images_directlink/001

# %%
Image(filename='predicted_images_directlink/001/IMG_20231030_155647.jpg', width=500)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
